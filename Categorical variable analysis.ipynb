# %%
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt
df= pd.read_csv("D:\Sem 2 DS\Machine Learning\Dataset\student-mat.csv",delimiter=";")
df1=df[df['age']<18]
df1.head()
sns.catplot(x="Dalc", y="age", hue="address", kind="bar", data=df1);
sns.catplot(x="Walc", y="age", hue="address", kind="bar", data=df1);
sns.catplot(x="age",y="absences",data=df)
sns.catplot(x="Dalc", y="age", hue="address",kind="box", data=df);

# %%
df1.hist(bins=50,figsize=(30,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012E810ED6D8>,
# ...
#       dtype=object)

# %%
df1['Medu'].astype('category')

sns.scatterplot(y="Walc", x="age",hue="Medu" , data=df);

# %%
df1.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  284.000000  284.000000  284.000000  284.000000  284.000000  284.000000
# mean    16.056338    2.813380    2.591549    1.411972    2.007042    0.246479
# std      0.795523    1.075111    1.074306    0.685022    0.844826    0.674488
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     15.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     16.000000    3.000000    3.000000    1.000000    2.000000    0.000000
# 75%     17.000000    4.000000    4.000000    2.000000    2.000000    0.000000
# max     17.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  284.000000  284.000000  284.000000  284.000000  284.000000  284.000000
# mean     3.908451    3.242958    3.059859    1.440141    2.271127    3.598592
# ...

# %%
df1['Medu'].astype('category')
df1['Fedu'].astype('category')
df1['Medu'].astype('category')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284 entries, 1 to 391
# Data columns (total 33 columns):
# school        284 non-null object
# sex           284 non-null object
# age           284 non-null int64
# address       284 non-null object
# famsize       284 non-null object
# Pstatus       284 non-null object
# Medu          284 non-null int64
# Fedu          284 non-null int64
# Mjob          284 non-null object
# Fjob          284 non-null object
# reason        284 non-null object
# guardian      284 non-null object
# traveltime    284 non-null int64
# studytime     284 non-null int64
# failures      284 non-null int64
# schoolsup     284 non-null object
# famsup        284 non-null object
# paid          284 non-null object
# activities    284 non-null object
# nursery       284 non-null object
# higher        284 non-null object
# internet      284 non-null object
# romantic      284 non-null object
# famrel        284 non-null int64
# ...

# %%
contingency_table=pd.crosstab(df1["age"],df1["Dalc"])
print('contingency_table :-\n',contingency_table)

contingency_table1=pd.crosstab(df1["age"],df1["Walc"])
print('contingency_table :-\n',contingency_table1)

from scipy import stats

stats.chi2_contingency(contingency_table)
# Out:
# contingency_table :-
#  Dalc   1   2  3  4  5
# age
# 15    62  14  4  1  1
# 16    76  18  6  1  3
# 17    65  22  6  3  2
# contingency_table :-
#  Walc   1   2   3   4  5
# age
# 15    46  12  13   8  3
# 16    42  23  15  16  8
# 17    25  23  27  15  8
# (20.60165787697444,
#  0.008284344039097872,
#  8,
#  array([[32.62676056, 16.74647887, 15.88028169, 11.26056338,  5.48591549],
#         [41.38028169, 21.23943662, 20.14084507, 14.28169014,  6.95774648],
#         [38.99295775, 20.01408451, 18.97887324, 13.45774648,  6.55633803]]))

# %%
stats.chi2_contingency(contingency_table1)
# Out:
# (20.60165787697444,
#  0.008284344039097872,
#  8,
#  array([[32.62676056, 16.74647887, 15.88028169, 11.26056338,  5.48591549],
#         [41.38028169, 21.23943662, 20.14084507, 14.28169014,  6.95774648],
#         [38.99295775, 20.01408451, 18.97887324, 13.45774648,  6.55633803]]))
